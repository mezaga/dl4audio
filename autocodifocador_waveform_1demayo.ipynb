# %%
# mount your Google drive so that you only have to download the data only once
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
######load your data#######
import os
from os import walk
import numpy as np
# load your data
paths = ["/content/drive/MyDrive/sintesis_dataset/am","/content/drive/MyDrive/sintesis_dataset/fm",
         "/content/drive/MyDrive/sintesis_dataset/grain","/content/drive/MyDrive/sintesis_dataset/res",
         "/content/drive/MyDrive/sintesis_dataset/waveshapping"]
#print(paths)
audios = []
labels = []
labelsname = []
for i in paths:
    for (dirpath, dirnames, filenames) in walk(i):
        for filename in filenames:
            audios.append(os.path.join(dirpath, filename))
            #audios.append(filename)
            #print(audios)
            if filename.startswith("am"):
                labels.append(0)
                labelsname.append("am")
            elif filename.startswith("fm"):
                labels.append(1)
                labelsname.append("fm")
            elif filename.startswith("grain"):
                labels.append(2)
                labelsname.append("grain")
            elif filename.startswith("res"):
                labels.append(3)
                labelsname.append("res")
            elif filename.startswith("waveshapping"):
                labels.append(4)
                labelsname.append("waveshapping")
        #print(filenames)
        #audios.append(filenames)
        break

# %%
###rawwaveform
import librosa
import numpy as np

waveforms = []
#nsr = 22050

for track in audios:
    y,fs = librosa.load(track)
    #y = librosa.resample(y,fs,nsr)
    waveforms.append(y[:48000])#[...,np.newaxis][...,np.newaxis][...,np.newaxis])

#data = np.array(data)
#datastft = np.array(datastft)
waveforms = np.array(waveforms)

#print(data.shape)
#print(datastft.shape)
print(waveforms.shape)
# Out:
# (1000, 48000)

# %%
#waveforms = waveforms.tolist()
waveforms = [waveforms[i] for i in range(0,1000,4)]
waveforms = np.array(waveforms)
print(waveforms.shape)
# Out:
# (250, 48000)

# %%
print(waveforms[0])
# Out:
# [ 0.02980709  0.04320773  0.0374092  ... -0.21012735 -0.20449625
#  -0.19853391]

# %%
# visualize a few raw datapoints to get an idea about your "raw" data
# what are the units in the plot you are showing us?
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(15, 6)).suptitle("Raw waveform")
sonidos = [0,50,100,150,200]
#sonidos = [i for i in range(5)]
labelsname = ["Am","Fm","Grain","Res","Waveshapping"]

for i, x in enumerate(sonidos):
    plt.subplot(2, 5, i+ 1).set_title(labelsname[i])
    librosa.display.waveplot(waveforms[x])
plt.tight_layout()

plt.show()

# %%
###normalizar y cambio de dimensionalidad
mu_wave = np.mean(waveforms, axis= 1)[...,np.newaxis]#[...,np.newaxis][...,np.newaxis]
max_wave = np.max(waveforms, axis=1)[...,np.newaxis]#[...,np.newaxis][...,np.newaxis]

#X = (data-mu_)/s_
Xw = (waveforms-mu_wave)/max_wave
Xw = Xw
print(Xw.shape)
# Out:
# (1000, 48000)

# %%
# visualize a few raw datapoints to get an idea about your "raw" data
# what are the units in the plot you are showing us?
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(15, 6)).suptitle("Raw waveform")
sonidos = [0,50,100,150,200]
#sonidos = [i for i in range(5)]
labelsname = ["Am","Am","Fm","Fm","Grain","Grain","Res","Res","Waveshapping","Waveshapping"]

for i, x in enumerate(sonidos):
    plt.subplot(2, 5, i+ 1).set_title(labelsname[i])
    librosa.display.waveplot(Xw[x])
plt.tight_layout()

plt.show()

# %%
Ntracks = 250
track_idx = np.random.choice(Ntracks,Ntracks,replace=False)

### 85% de entrenamiento
### 100% de validación
### 50% de testeo

tr_tracks = [waveforms[i] for i in track_idx[:225]]
vl_tracks = [waveforms[i] for i in track_idx[225:]]

tr_tracks = np.array(tr_tracks)
vl_tracks = np.array(vl_tracks)
#print(len(tr_tracks))
print(tr_tracks.shape)
print(vl_tracks.shape)
#ts_tracks = [all_tracks[i] for i in track_idx[-50:]]
# Out:
# (225, 48000)
# (25, 48000)

# %%
Ntracks = 250
track_idx = np.random.choice(Ntracks,Ntracks,replace=False)
tr_tracks = [waveforms[i] for i in track_idx[0:]]
tr_tracks = np.array(tr_tracks)
print(tr_tracks.shape)
# Out:
# (250, 48000)

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model

input = layers.Input((48000,1))

# Encoder
#x = layers.Conv1D(64, 4, activation="relu", padding="same",strides=4)(input)

x = layers.Conv1D(4, 64, activation="relu", padding="same",strides=4)(input)
x = layers.Conv1D(4,128, activation="relu", padding="same",strides=4)(x)
x = layers.Conv1D(4,256, activation="relu", padding="same",strides=4)(x)
latent = layers.Conv1D(4,512, activation="relu", padding="same",strides=3)(x)

# Decoder
x = layers.Conv1DTranspose(4,512, activation="relu",padding= "same")(latent)
x = layers.Conv1DTranspose(4,256, activation="relu",padding= "same",strides= 3)(x)
x = layers.Conv1DTranspose(4,128, activation="relu",padding= "same",strides= 4)(x)
x = layers.Conv1DTranspose(4,64, activation="relu",padding= "same",strides=4)(x)
x = layers.Conv1DTranspose(1,1, activation="tanh", padding="same",strides=4)(x) #aguas con Relu si tus espectrogramas tienen valores negativos
#x = layers.Conv1D(1,1, activation="tanh", padding="same")(x)
# Autoencoder
#autoencoder = Model(inputs=input, outputs=(x,latent))
autoencoder = Model(input, x)

autoencoder.compile(optimizer="adam", loss="mean_squared_error")
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48000, 1)]        0
#
#  conv1d_12 (Conv1D)          (None, 12000, 4)          260
#
#  conv1d_13 (Conv1D)          (None, 3000, 4)           2052
#
#  conv1d_14 (Conv1D)          (None, 750, 4)            4100
#
#  conv1d_15 (Conv1D)          (None, 250, 4)            8196
#
#  conv1d_transpose_15 (Conv1D  (None, 250, 4)           8196
#  Transpose)
#
#  conv1d_transpose_16 (Conv1D  (None, 750, 4)           4100
#  Transpose)
#
#  conv1d_transpose_17 (Conv1D  (None, 3000, 4)          2052
#  Transpose)
#
#  conv1d_transpose_18 (Conv1D  (None, 12000, 4)         1028
#  Transpose)
#
#  conv1d_transpose_19 (Conv1D  (None, 48000, 1)         5
#  Transpose)
#
# =================================================================
# Total params: 29,989
# Trainable params: 29,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model

input = layers.Input((48000,1))

# Encoder
#x = layers.Conv1D(64, 4, activation="relu", padding="same",strides=4)(input)

x = layers.Conv1D(64, 4, activation="relu", padding="same",strides=4)(input)
x = layers.Conv1D(128,4, activation="relu", padding="same",strides=4)(x)
x = layers.Conv1D(256,4, activation="relu", padding="same",strides=4)(x)
latent = layers.Conv1D(512,4, activation="relu", padding="same",strides=3)(x)

# Decoder
x = layers.Conv1DTranspose(512,4, activation="relu",padding= "same")(latent)
x = layers.Conv1DTranspose(256,4, activation="relu",padding= "same",strides= 3)(x)
x = layers.Conv1DTranspose(128,4, activation="relu",padding= "same",strides= 4)(x)
x = layers.Conv1DTranspose(64,4, activation="relu",padding= "same",strides=4)(x)
x = layers.Conv1DTranspose(1,1, activation="tanh", padding="same",strides=4)(x) #aguas con Relu si tus espectrogramas tienen valores negativos
#x = layers.Conv1D(1,1, activation="tanh", padding="same")(x)
# Autoencoder
#autoencoder = Model(inputs=input, outputs=(x,latent))
autoencoder = Model(input, x)

autoencoder.compile(optimizer="adam", loss="mean_squared_error")
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48000, 1)]        0
#
#  conv1d (Conv1D)             (None, 12000, 64)         320
#
#  conv1d_1 (Conv1D)           (None, 3000, 128)         32896
#
#  conv1d_2 (Conv1D)           (None, 750, 256)          131328
#
#  conv1d_3 (Conv1D)           (None, 250, 512)          524800
#
#  conv1d_transpose (Conv1DTra  (None, 250, 512)         1049088
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 750, 256)         524544
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 3000, 128)        131200
#  ranspose)
#
#  conv1d_transpose_3 (Conv1DT  (None, 12000, 64)        32832
#  ranspose)
#
#  conv1d_transpose_4 (Conv1DT  (None, 48000, 1)         65
#  ranspose)
#
# =================================================================
# Total params: 2,427,073
# Trainable params: 2,427,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
tr_logs = autoencoder.fit(
    x= waveforms,
    y= waveforms,
    epochs= 500,
    batch_size= 2,
    shuffle=True,
   #validation_data=(vl_tracks,vl_tracks),
)
# Out:
# Epoch 1/500
# 500/500 [==============================] - 20s 19ms/step - loss: 0.0496
# Epoch 2/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0478
# Epoch 3/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0460
# Epoch 4/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0454
# Epoch 5/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0448
# Epoch 6/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0443
# Epoch 7/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0438
# Epoch 8/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0429
# Epoch 9/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0425
# Epoch 10/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0419
# Epoch 11/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0420
# Epoch 12/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0415
# Epoch 13/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0408
# Epoch 14/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0407
# Epoch 15/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0405
# Epoch 16/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0405
# Epoch 17/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0405
# Epoch 18/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0401
# Epoch 19/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0400
# Epoch 20/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0400
# Epoch 21/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0399
# Epoch 22/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0398
# Epoch 23/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0397
# Epoch 24/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0397
# Epoch 25/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0396
# Epoch 26/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0396
# Epoch 27/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0395
# Epoch 28/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0395
# Epoch 29/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0394
# Epoch 30/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0395
# Epoch 31/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0395
# Epoch 32/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0394
# Epoch 33/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0394
# Epoch 34/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0393
# Epoch 35/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0392
# Epoch 36/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0392
# Epoch 37/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0393
# Epoch 38/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0391
# Epoch 39/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0392
# Epoch 40/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0391
# Epoch 41/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0391
# Epoch 42/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0389
# Epoch 43/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0389
# Epoch 44/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0390
# Epoch 45/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0389
# Epoch 46/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0388
# Epoch 47/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0388
# Epoch 48/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0388
# Epoch 49/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0388
# Epoch 50/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 51/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 52/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0388
# Epoch 53/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 54/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 55/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 56/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 57/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 58/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 59/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 60/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 61/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 62/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 63/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 64/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 65/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 66/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 67/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0387
# Epoch 68/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 69/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 70/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 71/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 72/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 73/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 74/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 75/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 76/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 77/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 78/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 79/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 80/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 81/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 82/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 83/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 84/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0386
# Epoch 85/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 86/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 87/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 88/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 89/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 90/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 91/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 92/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 93/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 94/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 95/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 96/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 97/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 98/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 99/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0385
# Epoch 100/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 101/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 102/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 103/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 104/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 105/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 106/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 107/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 108/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 109/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 110/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 111/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 112/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 113/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 114/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 115/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 116/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 117/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 118/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 119/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0383
# Epoch 120/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 121/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 122/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 123/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 124/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 125/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 126/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 127/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 128/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 129/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 130/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 131/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 132/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 133/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 134/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 135/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 136/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 137/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 138/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 139/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 140/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 141/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 142/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0383
# Epoch 143/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 144/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0384
# Epoch 145/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 146/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 147/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 148/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 149/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 150/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 151/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 152/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 153/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 154/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 155/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 156/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 157/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 158/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 159/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 160/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 161/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 162/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 163/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 164/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 165/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 166/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 167/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 168/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 169/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 170/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 171/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 172/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 173/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 174/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 175/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 176/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 177/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 178/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 179/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 180/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 181/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 182/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 183/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 184/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 185/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 186/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 187/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0383
# Epoch 188/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 189/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 190/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 191/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 192/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 193/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 194/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 195/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 196/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 197/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 198/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 199/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 200/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 201/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 202/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 203/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 204/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 205/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 206/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 207/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 208/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 209/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 210/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 211/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 212/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 213/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 214/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 215/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 216/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 217/500
# 500/500 [==============================] - 11s 22ms/step - loss: 0.0382
# Epoch 218/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 219/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 220/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 221/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 222/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 223/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 224/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 225/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 226/500
# 500/500 [==============================] - 11s 21ms/step - loss: 0.0382
# Epoch 227/500
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0382
# Epoch 228/500
# 500/500 [==============================] - 11s 21ms/step - loss: 0.0382
# Epoch 229/500
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0382
# Epoch 230/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 231/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 232/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 233/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 234/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 235/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 236/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 237/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 238/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 239/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 240/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 241/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 242/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0383
# Epoch 243/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 244/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 245/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 246/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 247/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 248/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 249/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 250/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 251/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 252/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 253/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 254/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 255/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 256/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 257/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 258/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 259/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 260/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 261/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 262/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 263/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 264/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 265/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 266/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 267/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 268/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 269/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 270/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 271/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 272/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 273/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 274/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 275/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 276/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 277/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 278/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 279/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 280/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 281/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0383
# Epoch 282/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 283/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 284/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 285/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 286/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 287/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 288/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 289/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 290/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 291/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 292/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 293/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 294/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 295/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 296/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 297/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 298/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 299/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 300/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 301/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 302/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 303/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 304/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 305/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 306/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 307/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 308/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 309/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 310/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 311/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 312/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 313/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 314/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 315/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 316/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 317/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 318/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 319/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 320/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 321/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 322/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 323/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 324/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 325/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 326/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 327/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 328/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 329/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 330/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 331/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 332/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 333/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 334/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 335/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 336/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 337/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 338/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 339/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 340/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 341/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 342/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 343/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 344/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 345/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 346/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 347/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 348/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 349/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 350/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 351/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 352/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 353/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 354/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 355/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 356/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 357/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 358/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 359/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 360/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 361/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 362/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 363/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 364/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 365/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 366/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 367/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 368/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 369/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 370/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 371/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 372/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 373/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 374/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 375/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 376/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 377/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 378/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 379/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 380/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 381/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 382/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 383/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 384/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 385/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 386/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 387/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 388/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 389/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 390/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 391/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 392/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 393/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 394/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 395/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 396/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 397/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 398/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 399/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 400/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 401/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 402/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 403/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 404/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 405/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 406/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 407/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 408/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 409/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 410/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 411/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 412/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 413/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 414/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 415/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 416/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 417/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 418/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 419/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 420/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 421/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 422/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 423/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 424/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 425/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 426/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 427/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 428/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 429/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 430/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 431/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 432/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 433/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 434/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 435/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 436/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 437/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 438/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 439/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 440/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 441/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 442/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 443/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 444/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 445/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 446/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 447/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 448/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 449/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 450/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 451/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 452/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 453/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0381
# Epoch 454/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 455/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 456/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 457/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 458/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 459/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 460/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 461/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 462/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0381
# Epoch 463/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 464/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 465/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 466/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 467/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 468/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 469/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 470/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 471/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 472/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0381
# Epoch 473/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 474/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 475/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 476/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 477/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0381
# Epoch 478/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 479/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 480/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 481/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 482/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 483/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 484/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 485/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 486/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 487/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 488/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 489/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 490/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 491/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0382
# Epoch 492/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 493/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 494/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 495/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 496/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 497/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 498/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 499/500
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0382
# Epoch 500/500
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0381

# %%
autoencoder.save('/content/drive/MyDrive/sintesis_dataset/autoencoder')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/sintesis_dataset/autoencoder/assets

# %%
###CNN
import matplotlib.pyplot as plt

# summarize history for loss
plt.plot(tr_logs.history['loss'])
#plt.plot(tr_logs.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
from keras.models import load_model

model = load_model('/content/drive/MyDrive/sintesis_dataset/autoencoder')
#model.summary()
layer_name = 'conv1d_3'
intermediate_layer_model = Model(inputs=model.input,outputs=model.get_layer(layer_name).output)
intermediate_output = intermediate_layer_model(waveforms[:700])

# %%
print(intermediate_output.shape)
print(intermediate_output[0].shape)
latent = []
for i in range(len(waveforms[:700])):
  latent.append(intermediate_output[0].numpy().flatten())
latent = np.array(latent)

print(latent.shape)
# Out:
# (700, 250, 512)
# (250, 512)
# (700, 128000)

# %%
# plot ALL of your training data using t-SNE and PCA (must plot both)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE 
###t-SNE
## for t-SNE
fig = plt.figure(1, figsize=(12, 6))
ax = Axes3D(fig,elev=-20, azim=100)
tsne = TSNE(n_components= 3)  # create an instance of t-SNE
ax = plt.axes(projection = "3d")
X_tsne = tsne.fit_transform(latent)  # fit and transform the data
ax.scatter3D(X_tsne[:199, 0], X_tsne[:199, 1], X_tsne[:199, 2], c='red', label='am')
ax.scatter3D(X_tsne[200:399, 0], X_tsne[200:399, 1], X_tsne[200:399, 2], c='green', label='fm')
ax.scatter3D(X_tsne[400:599, 0], X_tsne[400:599, 1], X_tsne[400:599, 2], c='blue', label='grain')
ax.scatter3D(X_tsne[600:799, 0], X_tsne[600:799, 1], X_tsne[600:799, 2], c='orange', label='res')
#ax.scatter3D(X_tsne[800:999, 0], X_tsne[800:999, 1], X_tsne[800:999, 2], c='yellow', label='waveshapping')
ax.view_init(30,60)
plt.title('T-SNE 3D')
ax.set_xlabel('TSNE 1')
ax.set_ylabel('TSNE 2')
ax.set_zlabel('TSNE 3')
ax.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
fig = plt.figure(1, figsize=(12, 6))
#a3x = Axes3D(fig,elev=-20, azim=100)
tsne = TSNE(n_components= 2)  # create an instance of t-SNE
#ax = plt.axes(projection = "3d")
X_tsne = tsne.fit_transform(latent)  # fit and transform the data
plt.scatter(X_tsne[:199, 0], X_tsne[:199, 1], c='red', label='am')
plt.scatter(X_tsne[200:399, 0], X_tsne[200:399, 1], c='green', label='fm')
plt.scatter(X_tsne[400:599, 0], X_tsne[400:599, 1], c='blue', label='grain')
plt.scatter(X_tsne[600:799, 0], X_tsne[600:799, 1], c='orange', label='res')
plt.scatter(X_tsne[800:999, 0], X_tsne[800:999, 1], c='yellow', label='waveshapping')
#ax.view_init(30,60)
plt.title('T-SNE 3D')
ax.set_xlabel('TSNE 1')
ax.set_ylabel('TSNE 2')
#ax.set_zlabel('TSNE 3')
ax.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
a = autoencoder.predict(tr_tracks)
print(a.shape)
#for i in a:
#  print(i)
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(15, 6)).suptitle("Raw waveform")
labelsname = ["Am","Am","Fm","Fm","Grain","Grain","Res","Res","Waveshapping","Waveshapping"]

for i in range(5):
    plt.subplot(2, 5, i+ 1).set_title(labelsname[i])
    librosa.display.waveplot(a[i].flatten(),sr=48000,color='r')
plt.tight_layout()

plt.show()
# Out:
# (225, 48000, 1)

# %%
import IPython
sr = 48000
IPython.display.Audio(data= a[0].flatten(), rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 6)).suptitle("Raw waveform")
labelsname = ["Am","Am","Fm","Fm","Grain","Grain","Res","Res","Waveshapping","Waveshapping"]

for i in range(5):
    plt.subplot(2, 5, i+ 1).set_title(labelsname[i])
    librosa.display.waveplot(tr_tracks[i],sr)
plt.tight_layout()

plt.show()

# %%
import IPython
sr = 48000
IPython.display.Audio(data= tr_tracks[0], rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
